# %% [markdown]
# # Adım 7: Görselleştirme ve Dashboard
# Projemizin interaktif dashboard'u **Streamlit** kullanılarak geliştirilmiştir ve `ml_pipeline/dashboard.py` dosyası içinde yer almaktadır.
#
# **Dashboard'u çalıştırmak için terminale şu komutu yazınız:**
# `streamlit run ../ml_pipeline/dashboard.py`
#
# Aşağıda MLflow tarafından üretilen bazı örnek grafikler listelenmiştir:

# %%
from IPython.display import Image, display
import os

# Rastgele bir modelin scatter grafiğini gösterelim
path = "../ml_pipeline/temp_plots/Random_Forest_scatter.png"
if os.path.exists(path):
    display(Image(filename=path))
else:
    print("Grafikler henüz oluşturulmamış. Lütfen önce Adım 6'yı çalıştırın.")
